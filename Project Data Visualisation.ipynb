# %%
import pandas as pd
df1=pd.read_csv('ObesityDataSet_raw_and_data_sinthetic.csv')
df1 = df1.rename(columns={'FAVC': 'frequent_cons_high_caloric_food', 'FCVC': 'frequency_cons_veg', 
                           'NCP': 'nb_main_meal', 'CAEC': 'cons_between_meal', 
                           'SCC': 'Suivi_calories', 'FAF': 'frequency_phys_act', 
                           'TUE': 'time_tech', 'CALC': 'cons_alcohol'})
df1['Gender'] = df1['Gender'].replace(['Male','Female'],[0,1])
df1['family_history_with_overweight'] = df1['family_history_with_overweight'].replace(['yes','no'],[1,0])
df1['frequent_cons_high_caloric_food'] = df1['frequent_cons_high_caloric_food'].replace(['yes','no'],[1,0])
df1['cons_between_meal'] = df1['cons_between_meal'].replace(['no','Sometimes','Frequently','Always'],[0,1,2,3])
df1['SMOKE'] = df1['SMOKE'].replace(['yes','no'],[1,0])
df1['Suivi_calories'] = df1['Suivi_calories'].replace(['yes','no'],[1,0])
df1['MTRANS'] = df1['MTRANS'].map({'Public_Transportation':0,
                             'Walking':1,'Automobile':2,
                             'Motorbike':3,'Bike':4},na_action=None)
df1['cons_alcohol'] = df1['cons_alcohol'].map({'no':0,
                             'Sometimes':1,'Frequently':2,
                             'Always':3},na_action=None)
df1['NObeyesdad'] = df1['NObeyesdad'].map({'Insufficient_Weight':0,
                             'Normal_Weight':1,'Overweight_Level_I':2,
                             'Overweight_Level_II':3,'Obesity_Type_I':4,
                            'Obesity_Type_II':5,'Obesity_Type_III':6},na_action=None)
df1.head(10)
# Out:
#    Gender   Age  Height  Weight  family_history_with_overweight  \
# 0       1  21.0    1.62    64.0                               1
# 1       1  21.0    1.52    56.0                               1
# 2       0  23.0    1.80    77.0                               1
# 3       0  27.0    1.80    87.0                               0
# 4       0  22.0    1.78    89.8                               0
# 5       0  29.0    1.62    53.0                               0
# 6       1  23.0    1.50    55.0                               1
# 7       0  22.0    1.64    53.0                               0
# 8       0  24.0    1.78    64.0                               1
# 9       0  22.0    1.72    68.0                               1
#
#    frequent_cons_high_caloric_food  frequency_cons_veg  nb_main_meal  \
# 0                                0                 2.0           3.0
# 1                                0                 3.0           3.0
# 2                                0                 2.0           3.0
# 3                                0                 3.0           3.0
# 4                                0                 2.0           1.0
# 5                                1                 2.0           3.0
# 6                                1                 3.0           3.0
# 7                                0                 2.0           3.0
# 8                                1                 3.0           3.0
# 9                                1                 2.0           3.0
#
#    cons_between_meal  SMOKE  CH2O  Suivi_calories  frequency_phys_act  \
# 0                  1      0   2.0               0                 0.0
# 1                  1      1   3.0               1                 3.0
# 2                  1      0   2.0               0                 2.0
# 3                  1      0   2.0               0                 2.0
# 4                  1      0   2.0               0                 0.0
# 5                  1      0   2.0               0                 0.0
# 6                  1      0   2.0               0                 1.0
# 7                  1      0   2.0               0                 3.0
# 8                  1      0   2.0               0                 1.0
# 9                  1      0   2.0               0                 1.0
#
#    time_tech  cons_alcohol  MTRANS  NObeyesdad
# 0        1.0             0       0           1
# 1        0.0             1       0           1
# 2        1.0             2       0           1
# 3        0.0             2       1           2
# 4        0.0             1       0           3
# 5        0.0             1       2           1
# 6        0.0             1       3           1
# 7        0.0             1       0           1
# 8        1.0             2       0           1
# 9        1.0             0       0           1

# %%
df1.tail(10)
# Out:
#       Gender        Age    Height      Weight  family_history_with_overweight  \
# 2101       1  25.722004  1.628470  107.218949                               1
# 2102       1  25.765628  1.627839  108.107360                               1
# 2103       1  21.016849  1.724268  133.033523                               1
# 2104       1  21.682367  1.732383  133.043941                               1
# 2105       1  21.285965  1.726920  131.335786                               1
# 2106       1  20.976842  1.710730  131.408528                               1
# 2107       1  21.982942  1.748584  133.742943                               1
# 2108       1  22.524036  1.752206  133.689352                               1
# 2109       1  24.361936  1.739450  133.346641                               1
# 2110       1  23.664709  1.738836  133.472641                               1
#
#       frequent_cons_high_caloric_food  frequency_cons_veg  nb_main_meal  \
# 2101                                1                 3.0           3.0
# 2102                                1                 3.0           3.0
# 2103                                1                 3.0           3.0
# 2104                                1                 3.0           3.0
# 2105                                1                 3.0           3.0
# 2106                                1                 3.0           3.0
# 2107                                1                 3.0           3.0
# 2108                                1                 3.0           3.0
# 2109                                1                 3.0           3.0
# 2110                                1                 3.0           3.0
#
#       cons_between_meal  SMOKE      CH2O  Suivi_calories  frequency_phys_act  \
# 2101                  1      0  2.487070               0            0.067329
# 2102                  1      0  2.320068               0            0.045246
# 2103                  1      0  1.650612               0            1.537639
# 2104                  1      0  1.610768               0            1.510398
# 2105                  1      0  1.796267               0            1.728332
# 2106                  1      0  1.728139               0            1.676269
# 2107                  1      0  2.005130               0            1.341390
# 2108                  1      0  2.054193               0            1.414209
# 2109                  1      0  2.852339               0            1.139107
# 2110                  1      0  2.863513               0            1.026452
#
#       time_tech  cons_alcohol  MTRANS        NObeyesdad
# 2101   0.455823             1       0  Obesity_Type_III
# 2102   0.413106             1       0  Obesity_Type_III
# 2103   0.912457             1       0  Obesity_Type_III
# 2104   0.931455             1       0  Obesity_Type_III
# 2105   0.897924             1       0  Obesity_Type_III
# 2106   0.906247             1       0  Obesity_Type_III
# 2107   0.599270             1       0  Obesity_Type_III
# 2108   0.646288             1       0  Obesity_Type_III
# 2109   0.586035             1       0  Obesity_Type_III
# 2110   0.714137             1       0  Obesity_Type_III

# %% [markdown]
# ### Length of dataset

# %%
len(df1)
# Out:
# 2111

# %%
df1.shape[0]
# Out:
# 2111

# %% [markdown]
# ### Dataset columns

# %%
df1.columns
# Out:
# Index(['Gender', 'Age', 'Height', 'Weight', 'family_history_with_overweight',
#        'FAVC', 'FCVC', 'NCP', 'CAEC', 'SMOKE', 'CH2O', 'SCC', 'FAF', 'TUE',
#        'CALC', 'MTRANS', 'NObeyesdad'],
#       dtype='object')

# %%
df1.columns.shape[0]
# Out:
# 17

# %%
df1
# Out:
#       Gender        Age    Height      Weight family_history_with_overweight  \
# 0     Female  21.000000  1.620000   64.000000                            yes
# 1     Female  21.000000  1.520000   56.000000                            yes
# 2       Male  23.000000  1.800000   77.000000                            yes
# 3       Male  27.000000  1.800000   87.000000                             no
# 4       Male  22.000000  1.780000   89.800000                             no
# ...      ...        ...       ...         ...                            ...
# 2106  Female  20.976842  1.710730  131.408528                            yes
# 2107  Female  21.982942  1.748584  133.742943                            yes
# 2108  Female  22.524036  1.752206  133.689352                            yes
# 2109  Female  24.361936  1.739450  133.346641                            yes
# 2110  Female  23.664709  1.738836  133.472641                            yes
#
#      frequent_cons_high_caloric_food  frequency_cons_veg  nb_main_meal  \
# 0                                 no                 2.0           3.0
# 1                                 no                 3.0           3.0
# 2                                 no                 2.0           3.0
# 3                                 no                 3.0           3.0
# 4                                 no                 2.0           1.0
# ...                              ...                 ...           ...
# 2106                             yes                 3.0           3.0
# 2107                             yes                 3.0           3.0
# 2108                             yes                 3.0           3.0
# 2109                             yes                 3.0           3.0
# 2110                             yes                 3.0           3.0
#
#      cons_between_meal SMOKE      CH2O Suivi_calories  frequency_phys_act  \
# 0            Sometimes    no  2.000000             no            0.000000
# 1            Sometimes   yes  3.000000            yes            3.000000
# 2            Sometimes    no  2.000000             no            2.000000
# 3            Sometimes    no  2.000000             no            2.000000
# 4            Sometimes    no  2.000000             no            0.000000
# ...                ...   ...       ...            ...                 ...
# 2106         Sometimes    no  1.728139             no            1.676269
# 2107         Sometimes    no  2.005130             no            1.341390
# 2108         Sometimes    no  2.054193             no            1.414209
# 2109         Sometimes    no  2.852339             no            1.139107
# 2110         Sometimes    no  2.863513             no            1.026452
#
#       time_tech cons_alcohol                 MTRANS           NObeyesdad
# 0      1.000000           no  Public_Transportation        Normal_Weight
# 1      0.000000    Sometimes  Public_Transportation        Normal_Weight
# 2      1.000000   Frequently  Public_Transportation        Normal_Weight
# 3      0.000000   Frequently                Walking   Overweight_Level_I
# 4      0.000000    Sometimes  Public_Transportation  Overweight_Level_II
# ...         ...          ...                    ...                  ...
# 2106   0.906247    Sometimes  Public_Transportation     Obesity_Type_III
# 2107   0.599270    Sometimes  Public_Transportation     Obesity_Type_III
# 2108   0.646288    Sometimes  Public_Transportation     Obesity_Type_III
# 2109   0.586035    Sometimes  Public_Transportation     Obesity_Type_III
# 2110   0.714137    Sometimes  Public_Transportation     Obesity_Type_III
#
# [2111 rows x 17 columns]

# %%
df1['cons_between_meal'].unique()
# Out:
# array(['Sometimes', 'Frequently', 'Always', 'no'], dtype=object)

# %%
df1['Age'].describe()
# Out:
# count    2111.000000
# mean       24.312600
# std         6.345968
# min        14.000000
# 25%        19.947192
# 50%        22.777890
# 75%        26.000000
# max        61.000000
# Name: Age, dtype: float64

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2111 entries, 0 to 2110
# Data columns (total 17 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Gender                          2111 non-null   object
#  1   Age                             2111 non-null   float64
#  2   Height                          2111 non-null   float64
#  3   Weight                          2111 non-null   float64
#  4   family_history_with_overweight  2111 non-null   object
#  5   FAVC                            2111 non-null   object
#  6   FCVC                            2111 non-null   float64
#  7   NCP                             2111 non-null   float64
#  8   CAEC                            2111 non-null   object
#  9   SMOKE                           2111 non-null   object
#  10  CH2O                            2111 non-null   float64
#  11  SCC                             2111 non-null   object
#  12  FAF                             2111 non-null   float64
#  13  TUE                             2111 non-null   float64
#  14  CALC                            2111 non-null   object
#  15  MTRANS                          2111 non-null   object
#  16  NObeyesdad                      2111 non-null   object
# dtypes: float64(8), object(9)
# memory usage: 296.9+ KB

# %%
# Drop empties
df1.dropna(inplace=True)

# %%
len(df1)
# Out:
# 2111

# %% [markdown]
# ### Minimums and maximums

# %%
df1['Age'].max(), df1['Age'].min()
# Out:
# (61.0, 14.0)

# %%
df1['Weight'].max(), df1['Weight'].min()
# Out:
# (173.0, 39.0)

# %%
df1['Height'].max(), df1['Height'].min()
# Out:
# (1.98, 1.45)

# %%
df1.isna().sum()
# Out:
# Gender                            0
# Age                               0
# Height                            0
# Weight                            0
# family_history_with_overweight    0
# FAVC                              0
# FCVC                              0
# NCP                               0
# CAEC                              0
# SMOKE                             0
# CH2O                              0
# SCC                               0
# FAF                               0
# TUE                               0
# CALC                              0
# MTRANS                            0
# NObeyesdad                        0
# dtype: int64

# %%
df2 = df1[df1["NObeyesdad"] == "Normal_Weight"]
len(df2)
# Out:
# 287

# %% [markdown]
# ### Data visualisation

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
columns = ['Gender', 'family_history_with_overweight']
fig, ax = plt.subplots(1, 2, figsize=(20, 10))
for col, subplot in zip(columns, ax.flatten()):
    sns.countplot(df1[col], ax=subplot)
    sns.countplot(df1[col],ax=subplot)  
    subplot.yaxis.label.set_text("Number of Records")
        
# show figure & plots
plt.tight_layout(pad=5, w_pad=0.0, h_pad=1)
plt.show()
# Out:
# C:\Users\prath\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\prath\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\prath\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\prath\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
dfMale=df1[df1['Gender']=='Male']
len(dfMale)
# Out:
# 1068

# %%
dfFemale=df1[df1['Gender']=='Female']
len(dfFemale)
# Out:
# 1043

# %%
dftest=df1.groupby('Gender').count()
# Out:
#          Age  Height  Weight  family_history_with_overweight  FAVC  FCVC  \
# Gender
# Female  1043    1043    1043                            1043  1043  1043
# Male    1068    1068    1068                            1068  1068  1068
#
#          NCP  CAEC  SMOKE  CH2O   SCC   FAF   TUE  CALC  MTRANS  NObeyesdad
# Gender
# Female  1043  1043   1043  1043  1043  1043  1043  1043    1043        1043
# Male    1068  1068   1068  1068  1068  1068  1068  1068    1068        1068

# %%
df1.groupby('Gender').size().plot(kind='pie', autopct="%.1f%%", textprops={'fontsize': 20},
                                 colors=['tomato', 'royalblue'])

plt.ylabel('Per gender', size=22)
plt.tight_layout()
plt.show()

# %%
df1.groupby('SMOKE').size().plot(kind='pie', autopct="%.1f%%", textprops={'fontsize': 12},
                                 colors=['violet', 'lime'])

plt.ylabel('Smoke', size=18)
plt.tight_layout()
plt.show()

# %%
df1.groupby('NObeyesdad').size().plot(kind='pie', autopct="%.1f%%", textprops={'fontsize': 12})

plt.ylabel('Obesity Types', size=18)
plt.tight_layout()
plt.show()

# %%
plt.hist(df1['Age'],bins=30,align='right', color='purple', edgecolor='black')
# Out:
# (array([  2.,  72., 243., 288., 308., 313., 126., 277.,  54.,  47.,  94.,
#          49.,  55.,  24.,  29.,  50.,  31.,  20.,  11.,   4.,   2.,   2.,
#           0.,   2.,   1.,   0.,   6.,   0.,   0.,   1.]),
#  array([14.        , 15.56666667, 17.13333333, 18.7       , 20.26666667,
#         21.83333333, 23.4       , 24.96666667, 26.53333333, 28.1       ,
#         29.66666667, 31.23333333, 32.8       , 34.36666667, 35.93333333,
#         37.5       , 39.06666667, 40.63333333, 42.2       , 43.76666667,
#         45.33333333, 46.9       , 48.46666667, 50.03333333, 51.6       ,
#         53.16666667, 54.73333333, 56.3       , 57.86666667, 59.43333333,
#         61.        ]),
#  <BarContainer object of 30 artists>)

# %%
fig = plt.figure(figsize = (12,7))
sns.distplot(df1["Age"], kde=True)
# Out:
# C:\Users\prath\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %%
df1.plot_bokeh.scatter(x='Height', 
    y='Weight', 
    title='Scatter Obesity')
# Out:
# Figure(id='1002', ...)

# %%
import pandas_bokeh

# %%
df1.plot_bokeh(kind='hist', bins=30)
# Out:
# Figure(id='1159', ...)

# %%
import warnings
warnings.filterwarnings('ignore')

import ipywidgets as widgets
from IPython.display import display, clear_output

# %%
# !jupyter nbextension enable --py widgetsnbextension --sys prefix
# !jupyter serverextension enable voila --sys-prefix
# Out:
# Unrecognized alias: 'sys', it will have no effect.
# Enabling notebook extension jupyter-js-widgets/extension...
#       - Validating: ok
# Enabling: voila
# - Writing config: C:\Users\prath\anaconda3\etc\jupyter
#     - Validating...
#       voila 0.3.0 ok

# %%
import os
import sys
#path = r"C:\Users\prath\Documents\mysite\mysite/settings.py"
sys.path.append(r"C:\Users\prath\Documents\mysite\mysite")
os.environ['DJANGO_SETTINGS_MODULE'] = 'mysite.settings'
from django.core.wsgi import get_wsgi_application
application = get_wsgi_application()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-30-1840b2716434> in <module>
#       5 os.environ['DJANGO_SETTINGS_MODULE'] = 'mysite.settings'
#       6 from django.core.wsgi import get_wsgi_application
# ----> 7 application = get_wsgi_application()
#
# ~\anaconda3\lib\site-packages\django\core\wsgi.py in get_wsgi_application()
#      10     internal WSGI implementation changes or moves in the future.
#      11     """
# ---> 12     django.setup(set_prefix=False)
#      13     return WSGIHandler()
#
# ~\anaconda3\lib\site-packages\django\__init__.py in setup(set_prefix)
#      17     from django.utils.log import configure_logging
#      18
# ---> 19     configure_logging(settings.LOGGING_CONFIG, settings.LOGGING)
#      20     if set_prefix:
#      21         set_script_prefix(
#
# ~\anaconda3\lib\site-packages\django\conf\__init__.py in __getattr__(self, name)
#      80         """Return the value of a setting and cache it in self.__dict__."""
#      81         if self._wrapped is empty:
# ---> 82             self._setup(name)
#      83         val = getattr(self._wrapped, name)
#      84
#
# ~\anaconda3\lib\site-packages\django\conf\__init__.py in _setup(self, name)
#      67                 % (desc, ENVIRONMENT_VARIABLE))
#      68
# ---> 69         self._wrapped = Settings(settings_module)
#      70
#      71     def __repr__(self):
#
# ~\anaconda3\lib\site-packages\django\conf\__init__.py in __init__(self, settings_module)
#     168         self.SETTINGS_MODULE = settings_module
#     169
# --> 170         mod = importlib.import_module(self.SETTINGS_MODULE)
#     171
#     172         tuple_settings = (
#
# ~\anaconda3\lib\importlib\__init__.py in import_module(name, package)
#     125                 break
#     126             level += 1
# --> 127     return _bootstrap._gcd_import(name[level:], package, level)
#     128
#     129
#
# ~\anaconda3\lib\importlib\_bootstrap.py in _gcd_import(name, package, level)
#
# ~\anaconda3\lib\importlib\_bootstrap.py in _find_and_load(name, import_)
#
# ~\anaconda3\lib\importlib\_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'mysite.settings'

# %%
from django.shortcuts import render
from django.template import RequestContext
from django.http import HttpResponseRedirect
from wiki.models import Article, ArticleRevision, URLPath   
from django.http import HttpResponse
from matplotlib.backends.backend_agg import FigureCanvasAgg

import matplotlib.pyplot
import matplotlib.pyplot as plt
import numpy as np

#def index(request):
#    context = {'foo': 'bar'}
#    return render(request, 'index.html', context) 

def GraphsViewBar(request):
    f = plt.figure()
    x = np.arange(10)
    h = [0,1,2,3,5,6,4,2,1,0]
    plt.title('Title')
    plt.xlim(0, 10)
    plt.ylim(0, 8)
    plt.xlabel('x label')
    plt.ylabel('y label')
    bar1 = plt.bar(x,h,width=1.0,bottom=0,color='Green',alpha=0.65,label='Legend')
    plt.legend()

    canvas = FigureCanvasAgg(f)    
    response = HttpResponse(content_type='image/png')
    canvas.print_png(response)
    matplotlib.pyplot.close(f)   
    return response
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-28-5eededf90945> in <module>
#       2 from django.template import RequestContext
#       3 from django.http import HttpResponseRedirect
# ----> 4 from wiki.models import Article, ArticleRevision, URLPath
#       5 from django.http import HttpResponse
#       6 from matplotlib.backends.backend_agg import FigureCanvasAgg
#
# ~\anaconda3\lib\site-packages\wiki\models\__init__.py in <module>
#       4 from django.utils.functional import lazy
#       5
# ----> 6 from .article import *  # noqa
#       7 from .pluginbase import *  # noqa
#       8 from .urlpath import *  # noqa
#
# ~\anaconda3\lib\site-packages\wiki\models\article.py in <module>
#       1 from django.conf import settings as django_settings
# ----> 2 from django.contrib.contenttypes.fields import GenericForeignKey
#       3 from django.contrib.contenttypes.models import ContentType
#       4 from django.core.cache import cache
#       5 from django.db import models
#
# ~\anaconda3\lib\site-packages\django\contrib\contenttypes\fields.py in <module>
#       4 from collections import defaultdict
#       5
# ----> 6 from django.contrib.contenttypes.models import ContentType
#       7 from django.core import checks
#       8 from django.core.exceptions import FieldDoesNotExist, ObjectDoesNotExist
#
# ~\anaconda3\lib\site-packages\django\contrib\contenttypes\models.py in <module>
#     131
#     132
# --> 133 class ContentType(models.Model):
#     134     app_label = models.CharField(max_length=100)
#     135     model = models.CharField(_('python model class name'), max_length=100)
#
# ~\anaconda3\lib\site-packages\django\db\models\base.py in __new__(cls, name, bases, attrs, **kwargs)
#     106
#     107         # Look for an application configuration to attach the model to.
# --> 108         app_config = apps.get_containing_app_config(module)
#     109
#     110         if getattr(meta, 'app_label', None) is None:
#
# ~\anaconda3\lib\site-packages\django\apps\registry.py in get_containing_app_config(self, object_name)
#     251         Return None if the object isn't in any registered app config.
#     252         """
# --> 253         self.check_apps_ready()
#     254         candidates = []
#     255         for app_config in self.app_configs.values():
#
# ~\anaconda3\lib\site-packages\django\apps\registry.py in check_apps_ready(self)
#     133             # INSTALLED_APPS raises a more helpful ImproperlyConfigured
#     134             # exception.
# --> 135             settings.INSTALLED_APPS
#     136             raise AppRegistryNotReady("Apps aren't loaded yet.")
#     137
#
# ~\anaconda3\lib\site-packages\django\conf\__init__.py in __getattr__(self, name)
#      80         """Return the value of a setting and cache it in self.__dict__."""
#      81         if self._wrapped is empty:
# ---> 82             self._setup(name)
#      83         val = getattr(self._wrapped, name)
#      84
#
# ~\anaconda3\lib\site-packages\django\conf\__init__.py in _setup(self, name)
#      67                 % (desc, ENVIRONMENT_VARIABLE))
#      68
# ---> 69         self._wrapped = Settings(settings_module)
#      70
#      71     def __repr__(self):
#
# ~\anaconda3\lib\site-packages\django\conf\__init__.py in __init__(self, settings_module)
#     168         self.SETTINGS_MODULE = settings_module
#     169
# --> 170         mod = importlib.import_module(self.SETTINGS_MODULE)
#     171
#     172         tuple_settings = (
#
# ~\anaconda3\lib\importlib\__init__.py in import_module(name, package)
#     125                 break
#     126             level += 1
# --> 127     return _bootstrap._gcd_import(name[level:], package, level)
#     128
#     129
#
# ModuleNotFoundError: No module named 'mysite.settings'

# %%
# Out:
# Collecting wiki
#   Downloading wiki-0.7.9-py3-none-any.whl (2.9 MB)
# Requirement already satisfied: bleach<3.4,>=3.3.0 in c:\users\prath\anaconda3\lib\site-packages (from wiki) (3.3.0)
# Requirement already satisfied: Pillow in c:\users\prath\anaconda3\lib\site-packages (from wiki) (8.2.0)
# Collecting sorl-thumbnail<13,>=12.6.2
#   Downloading sorl_thumbnail-12.7.0-py3-none-any.whl (41 kB)
# Collecting django-mptt<0.12,>=0.11
#   Downloading django_mptt-0.11.0-py2.py3-none-any.whl (109 kB)
# Collecting django-sekizai>=0.10
#   Downloading django_sekizai-2.0.0-py3-none-any.whl (12 kB)
# Note: you may need to restart the kernel to use updated packages.Requirement already satisfied: Django<3.3,>=2.1 in c:\users\prath\anaconda3\lib\site-packages (from wiki) (3.2.2)
#
# Collecting Markdown<3.3,>=3.1
#   Downloading Markdown-3.2.2-py3-none-any.whl (88 kB)
# Collecting django-nyt<1.3,>=1.2
#   Downloading django_nyt-1.2-py3-none-any.whl (39 kB)
# Requirement already satisfied: six>=1.9.0 in c:\users\prath\anaconda3\lib\site-packages (from bleach<3.4,>=3.3.0->wiki) (1.15.0)
# Requirement already satisfied: webencodings in c:\users\prath\anaconda3\lib\site-packages (from bleach<3.4,>=3.3.0->wiki) (0.5.1)
# Requirement already satisfied: packaging in c:\users\prath\anaconda3\lib\site-packages (from bleach<3.4,>=3.3.0->wiki) (20.9)
# Requirement already satisfied: sqlparse>=0.2.2 in c:\users\prath\anaconda3\lib\site-packages (from Django<3.3,>=2.1->wiki) (0.4.1)
# Requirement already satisfied: asgiref<4,>=3.3.2 in c:\users\prath\anaconda3\lib\site-packages (from Django<3.3,>=2.1->wiki) (3.3.4)
# Requirement already satisfied: pytz in c:\users\prath\anaconda3\lib\site-packages (from Django<3.3,>=2.1->wiki) (2021.1)
# Collecting django-js-asset
#   Downloading django_js_asset-1.2.2-py2.py3-none-any.whl (5.8 kB)
# Collecting django-classy-tags>=1
#   Downloading django_classy_tags-2.0.0-py3-none-any.whl (23 kB)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\prath\anaconda3\lib\site-packages (from packaging->bleach<3.4,>=3.3.0->wiki) (2.4.7)
# Installing collected packages: django-js-asset, django-classy-tags, sorl-thumbnail, Markdown, django-sekizai, django-nyt, django-mptt, wiki
#   Attempting uninstall: Markdown
#     Found existing installation: Markdown 3.3.4
#     Uninstalling Markdown-3.3.4:
#       Successfully uninstalled Markdown-3.3.4
# Successfully installed Markdown-3.2.2 django-classy-tags-2.0.0 django-js-asset-1.2.2 django-mptt-0.11.0 django-nyt-1.2 django-sekizai-2.0.0 sorl-thumbnail-12.7.0 wiki-0.7.9

# %%
corr_df = df1.corr()
corr_df
# Out:
#                                    Gender       Age    Height    Weight  \
# Gender                           1.000000 -0.048394 -0.618466 -0.161668
# Age                             -0.048394  1.000000 -0.025958  0.202560
# Height                          -0.618466 -0.025958  1.000000  0.463136
# Weight                          -0.161668  0.202560  0.463136  1.000000
# family_history_with_overweight  -0.102512  0.205725  0.247684  0.496820
# frequent_cons_high_caloric_food -0.064934  0.063902  0.178364  0.272300
# frequency_cons_veg               0.274505  0.016291 -0.038121  0.216125
# nb_main_meal                    -0.067600 -0.043944  0.243672  0.107469
# cons_between_meal                0.091543 -0.083739 -0.048818 -0.287493
# SMOKE                           -0.044698  0.091987  0.055499  0.025746
# CH2O                            -0.107930 -0.045304  0.213376  0.200575
# Suivi_calories                   0.102633 -0.116283 -0.133753 -0.201906
# frequency_phys_act              -0.189607 -0.144938  0.294709 -0.051436
# time_tech                       -0.017269 -0.296931  0.051912 -0.071561
# cons_alcohol                     0.007616  0.044487  0.129732  0.206677
# MTRANS                          -0.164116  0.567983  0.085768 -0.046615
#
#                                  family_history_with_overweight  \
# Gender                                                -0.102512
# Age                                                    0.205725
# Height                                                 0.247684
# Weight                                                 0.496820
# family_history_with_overweight                         1.000000
# frequent_cons_high_caloric_food                        0.208036
# frequency_cons_veg                                     0.040372
# nb_main_meal                                           0.071370
# cons_between_meal                                     -0.169787
# SMOKE                                                  0.017385
# CH2O                                                   0.147437
# Suivi_calories                                        -0.185422
# frequency_phys_act                                    -0.056673
# time_tech                                              0.022943
# cons_alcohol                                          -0.036676
# MTRANS                                                 0.065036
#
#                                  frequent_cons_high_caloric_food  \
# Gender                                                 -0.064934
# Age                                                     0.063902
# Height                                                  0.178364
# Weight                                                  0.272300
# family_history_with_overweight                          0.208036
# frequent_cons_high_caloric_food                         1.000000
# frequency_cons_veg                                     -0.027283
# nb_main_meal                                           -0.007000
# cons_between_meal                                      -0.150068
# SMOKE                                                  -0.050660
# CH2O                                                    0.009719
# Suivi_calories                                         -0.190658
# frequency_phys_act                                     -0.107995
# time_tech                                               0.068417
# cons_alcohol                                            0.089520
# MTRANS                                                 -0.009102
#
#                                  frequency_cons_veg  nb_main_meal  \
# Gender                                     0.274505     -0.067600
# Age                                        0.016291     -0.043944
# Height                                    -0.038121      0.243672
# Weight                                     0.216125      0.107469
# family_history_with_overweight             0.040372      0.071370
# frequent_cons_high_caloric_food           -0.027283     -0.007000
# frequency_cons_veg                         1.000000      0.042216
# nb_main_meal                               0.042216      1.000000
# cons_between_meal                          0.054670      0.097801
# SMOKE                                      0.014320      0.007811
# CH2O                                       0.068461      0.057088
# Suivi_calories                             0.071852     -0.015624
# frequency_phys_act                         0.019939      0.129504
# time_tech                                 -0.101135      0.036326
# cons_alcohol                               0.060781      0.071747
# MTRANS                                    -0.065098      0.059022
#
#                                  cons_between_meal     SMOKE      CH2O  \
# Gender                                    0.091543 -0.044698 -0.107930
# Age                                      -0.083739  0.091987 -0.045304
# Height                                   -0.048818  0.055499  0.213376
# Weight                                   -0.287493  0.025746  0.200575
# family_history_with_overweight           -0.169787  0.017385  0.147437
# frequent_cons_high_caloric_food          -0.150068 -0.050660  0.009719
# frequency_cons_veg                        0.054670  0.014320  0.068461
# nb_main_meal                              0.097801  0.007811  0.057088
# cons_between_meal                         1.000000  0.055282 -0.144995
# SMOKE                                     0.055282  1.000000 -0.031995
# CH2O                                     -0.144995 -0.031995  1.000000
# Suivi_calories                            0.109179  0.047731  0.008036
# frequency_phys_act                        0.030110  0.011216  0.167236
# time_tech                                 0.048567  0.017613  0.011965
# cons_alcohol                             -0.047540  0.082471  0.091386
# MTRANS                                   -0.003556  0.021045 -0.035638
#
#                                  Suivi_calories  frequency_phys_act  \
# Gender                                 0.102633           -0.189607
# Age                                   -0.116283           -0.144938
# Height                                -0.133753            0.294709
# Weight                                -0.201906           -0.051436
# family_history_with_overweight        -0.185422           -0.056673
# frequent_cons_high_caloric_food       -0.190658           -0.107995
# frequency_cons_veg                     0.071852            0.019939
# nb_main_meal                          -0.015624            0.129504
# cons_between_meal                      0.109179            0.030110
# SMOKE                                  0.047731            0.011216
# CH2O                                   0.008036            0.167236
# Suivi_calories                         1.000000            0.074221
# frequency_phys_act                     0.074221            1.000000
# time_tech                             -0.010928            0.058562
# cons_alcohol                           0.003463           -0.086799
# MTRANS                                -0.012794            0.036098
#
#                                  time_tech  cons_alcohol    MTRANS
# Gender                           -0.017269      0.007616 -0.164116
# Age                              -0.296931      0.044487  0.567983
# Height                            0.051912      0.129732  0.085768
# Weight                           -0.071561      0.206677 -0.046615
# family_history_with_overweight    0.022943     -0.036676  0.065036
# frequent_cons_high_caloric_food   0.068417      0.089520 -0.009102
# frequency_cons_veg               -0.101135      0.060781 -0.065098
# nb_main_meal                      0.036326      0.071747  0.059022
# cons_between_meal                 0.048567     -0.047540 -0.003556
# SMOKE                             0.017613      0.082471  0.021045
# CH2O                              0.011965      0.091386 -0.035638
# Suivi_calories                   -0.010928      0.003463 -0.012794
# frequency_phys_act                0.058562     -0.086799  0.036098
# time_tech                         1.000000     -0.045864 -0.165571
# cons_alcohol                     -0.045864      1.000000 -0.025492
# MTRANS                           -0.165571     -0.025492  1.000000

# %%
corr_df = df1.corr(method='pearson')
plt.matshow(corr_df)
plt.show()

# %%
corr_df = df1.corr(method='pearson')
plt.figure(figsize=(20, 10))
sns.heatmap(corr_df, annot=True)
plt.show()
